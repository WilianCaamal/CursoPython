# %%
def ReadConfig():
    try:
        config = open('file.conf')
    except FileNotFoundError:
        print('Error: No se encontro el archivo de configuración')
    except IsADirectoryError:
        print('Directorio invalido')
    except Exception as Ex:
        print(f'Fatal Error: {Ex}')    

if __name__ == '__main__':
    ReadConfig();
# Out:
# Error: No se encontro el archivo de configuración
